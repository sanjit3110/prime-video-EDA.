# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Project Name**    - **Amazon Prime Video**

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual
# ##### **Name -** - sanjit

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Amazon Prime Video is a leading global streaming platform offering a vast library of movies and TV shows. In the highly competitive streaming industry, data-driven insights are essential for understanding audience preferences, optimizing content strategies, and driving user engagement.
#
# This project focuses on analyzing a dataset containing over 9,000 titles and 124,000 cast/crew credits available on Amazon Prime Video (U.S. region). By exploring various attributes such as genre, release year, age certification, ratings (IMDb, TMDB), and production countries, the project aims to uncover trends and patterns in the platform’s content library.
#
# The primary objective is to understand content diversity, regional production patterns, and how various features like runtime, popularity, and ratings relate to one another. Such insights can support better content acquisition strategies, improve recommendation systems, and enhance the overall viewer experience.
#
# Through visual storytelling and exploratory data analysis (EDA), this project provides valuable information that can benefit content managers, data analysts, and business decision-makers in the streaming domain.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# To improve content strategy and user engagement by analyzing factors like genre, release year, runtime, popularity, and ratings. This helps in making data-driven decisions to find high-performing content, expand variety, and invest better in original and licensed content.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/pandaswork/titles.csv/titles.csv')

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
df.head()
# Out:
#         id                        title   type  \
# 0  ts20945            The Three Stooges   SHOW
# 1  tm19248                  The General  MOVIE
# 2  tm82253  The Best Years of Our Lives  MOVIE
# 3  tm83884              His Girl Friday  MOVIE
# 4  tm56584            In a Lonely Place  MOVIE
#
#                                          description  release_year  \
# 0  The Three Stooges were an American vaudeville ...          1934
# 1  During America’s Civil War, Union spies steal ...          1926
# 2  It's the hope that sustains the spirit of ever...          1946
# 3  Hildy, the journalist former wife of newspaper...          1940
# 4  An aspiring actress begins to suspect that her...          1950
#
#   age_certification  runtime  \
# 0             TV-PG       19
# 1               NaN       78
# 2               NaN      171
# 3               NaN       92
# 4               NaN       94
#
#                                               genres production_countries  \
# ...

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
df.columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9871 entries, 0 to 9870
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    9871 non-null   object
#  1   title                 9871 non-null   object
#  2   type                  9871 non-null   object
#  3   description           9752 non-null   object
#  4   release_year          9871 non-null   int64
#  5   age_certification     3384 non-null   object
#  6   runtime               9871 non-null   int64
#  7   genres                9871 non-null   object
#  8   production_countries  9871 non-null   object
#  9   seasons               1357 non-null   float64
#  10  imdb_id               9204 non-null   object
#  11  imdb_score            8850 non-null   float64
#  12  imdb_votes            8840 non-null   float64
#  13  tmdb_popularity       9324 non-null   float64
#  14  tmdb_score            7789 non-null   float64
# ...

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
#9871 rows and 15 columns

# %% [markdown]
# ## **Data** **Wrangling**

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
df.duplicated().sum()
# Out:
# np.int64(3)

# %%
dublicated_rows =df[df.duplicated()]
dublicated_rows
# Out:
#            id                  title   type  \
# 480   tm89134  The Gunman From Bodie  MOVIE
# 720   tm66674               Dynamite  MOVIE
# 722  tm137955          Broken Dreams  MOVIE
#
#                                            description  release_year  \
# 480  The Rough Riders are after a gang of rustlers....          1941
# 720  Two members of a dynamite crew--a rugged veter...          1949
# 722  Medical intern Robert Morley is distraught aft...          1933
#
#     age_certification  runtime                genres production_countries  \
# 480               NaN       62           ['western']               ['US']
# 720               NaN       68    ['drama', 'crime']               ['US']
# 722               NaN       68  ['drama', 'romance']               ['US']
#
#      seasons    imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 480      NaN  tt0033683         5.9       133.0            0.991         7.0
# ...

# %%
df[df['id'] == 'tm137955']
# Out:
#            id          title   type  \
# 719  tm137955  Broken Dreams  MOVIE
# 722  tm137955  Broken Dreams  MOVIE
#
#                                            description  release_year  \
# 719  Medical intern Robert Morley is distraught aft...          1933
# 722  Medical intern Robert Morley is distraught aft...          1933
#
#     age_certification  runtime                genres production_countries  \
# 719               NaN       68  ['drama', 'romance']               ['US']
# 722               NaN       68  ['drama', 'romance']               ['US']
#
#      seasons    imdb_id  imdb_score  imdb_votes  tmdb_popularity  tmdb_score
# 719      NaN  tt0023849         5.8        74.0              0.6         NaN
# 722      NaN  tt0023849         5.8        74.0              0.6         NaN

# %%
df.drop_duplicates(inplace=True, keep='first')
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
df.isnull().mean()*100
# Out:
# id                       0.000000
# title                    0.000000
# type                     0.000000
# description              1.205918
# release_year             0.000000
# age_certification       65.707337
# runtime                  0.000000
# genres                   0.000000
# production_countries     0.000000
# seasons                 86.248480
# imdb_id                  6.759222
# imdb_score              10.346575
# imdb_votes              10.447912
# tmdb_popularity          5.543170
# tmdb_score              21.078233
# dtype: float64

# %%
# Visualizing the missing values
#tmdb_popularity,imdb_votes,tmdb_score,imdb_score = filling median value in these
#imdb_id,seasons,age_certification,description = droping these columns subset because the % of null value is grater or very less
df_visualizing_null = (df.isnull().mean()*100).sort_values(ascending=False)
df_visualizing_null
# Out:
# seasons                 86.248480
# age_certification       65.707337
# tmdb_score              21.078233
# imdb_votes              10.447912
# imdb_score              10.346575
# imdb_id                  6.759222
# tmdb_popularity          5.543170
# description              1.205918
# runtime                  0.000000
# title                    0.000000
# type                     0.000000
# id                       0.000000
# release_year             0.000000
# genres                   0.000000
# production_countries     0.000000
# dtype: float64

# %%
df.dropna(subset =['imdb_id'],inplace = True)

# %%
df['description'].fillna("No description available",inplace=True)
df['age_certification'].replace("N/A", np.nan, inplace=True)

df['seasons'].replace('N/A',np.nan, inplace=True)
# Out:
# /tmp/ipykernel_12235/3340904965.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['description'].fillna("No description available",inplace=True)
# /tmp/ipykernel_12235/3340904965.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# **So, in above code i filled the null value with something that is written in the code. In (age_certification and description) data may be not available so replacing the null value is good option
# as in droping we can loose lots of data**

# %%
df.isnull().sum().plot(kind='bar')
plt.title("Null Values Count per Column")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# *In these bar plot we can see the null value as par columns in decreasing order but we can ignore *

# %%
df[['tmdb_popular','tmdb_score','imdb_scoreity','imdb_votes']] = df[['tmdb_popularity','imdb_votes','tmdb_score','imdb_score']].fillna(df[['tmdb_popularity','imdb_votes','tmdb_score','imdb_score']].median())

# %% [markdown]
# **filled the null value with median as we can't drop thses data as the value of null is in higher side and for me filling with null value is good option rather then droping**

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# ```
# `# This is formatted as code`
# ```
#
# So, these data set is from amazon prime video and we have 9871 rows and 15 columns such as id,title,imdb_rating,imdb_score etc.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score', 'tmdb_popular', 'imdb_scoreity'],
#       dtype='object')

# %%
# Dataset Describe
df.describe()
# Out:
#        release_year      runtime      seasons   imdb_score   imdb_votes  \
# count   9201.000000  9201.000000  1249.000000  8847.000000  9201.000000
# mean    2000.623628    86.625693     2.884708     5.976534     5.981285
# std       26.297317    32.826648     4.062749     1.344028     1.318130
# min     1912.000000     1.000000     1.000000     1.100000     1.100000
# 25%     1994.000000    67.000000     1.000000     5.100000     5.200000
# 50%     2013.000000    90.000000     1.000000     6.100000     6.100000
# 75%     2018.000000   103.000000     3.000000     6.900000     6.900000
# max     2022.000000   549.000000    49.000000     9.900000     9.900000
#
#        tmdb_popularity    tmdb_score  tmdb_popular  imdb_scoreity
# count      8657.000000  9.201000e+03   9201.000000    9201.000000
# mean          7.078035  8.217130e+03      6.816350       5.983763
# std          29.300767  4.503744e+04     28.440451       1.336848
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Answer Here
#
# Variables Description
#
# This data set was created to list all shows available on Amazon Prime streaming, and analyze the data to find interesting facts. This dataset has data available in the United States.
#
# This dataset has two files containing the titles (titles.csv) and the cast (credits.csv) for the title.
#
# This dataset contains +9k unique titles on Amazon Prime with 15 columns containing their information, including:
#
# id: The title ID on JustWatch.
#
# title: The name of the title.
#
# show_type: TV show or movie.
#
# description: A brief description.
#
# release_year: The release year.
#
# age_certification: The age certification.
#
# runtime: The length of the episode (SHOW) or movie.
#
# genres: A list of genres.
#
# production_countries: A list of countries that produced the title.
#
# seasons: Number of seasons if it's a SHOW.
#
# imdb_id: The title ID on IMDB.
#
# imdb_score: Score on IMDB.
#
# imdb_votes: Votes on IMDB.
#
# tmdb_popularity: Popularity on TMDB.
#
# tmdb_score: Score on TMDB.
#
# And over +124k credits of actors and directors on Amazon Prime titles with 5 columns containing their information:
#
# person_ID: The person ID on JustWatch.
#
# id: The title ID on JustWatch.
#
# name: The actor or director's name.
#
# character_name: The character name.
#
# role: ACTOR or DIRECTOR.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable by getting the count of unique values per column.
df[['id', 'title', 'type', 'description', 'release_year',
       'age_certification', 'runtime', 'genres', 'production_countries',
       'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
       'tmdb_score']].nunique().sort_values(ascending=False)
# Out:
# id                      9201
# imdb_id                 9201
# description             9091
# title                   9087
# tmdb_popularity         5160
# tmdb_score              3650
# genres                  2023
# production_countries     485
# runtime                  203
# release_year             110
# imdb_votes                86
# imdb_score                86
# seasons                   31
# age_certification         11
# type                       2
# dtype: int64

# %%
def basic_clean(text):
  return str(text).lower().strip()

# %%
df['title'] = df['title'].apply(basic_clean)

# %%
def clean_text(text):
    if pd.isna(text):
        return ""
    text = text.lower()                     # Lowercase
    text = text.strip()                     # Strip outer whitespace
    text = text.replace('!', '').replace('#', '')  # Remove specific symbols
    for char in ['@', '$', '%', '^', '&', '*', '(', ')', '-', '_', '=', '+', '[', ']', '{', '}', '|', ':', ';', '"', "'", '<', '>', ',', '.', '?', '/','\\','[]']:
        text = text.replace(char, '')
    return ''.join([i for i in text if not i.isdigit()] )

# %%
#Dealing with string and white space

df['description'] = df['description'].apply(clean_text)
df['genres'] = df['genres'].apply(clean_text)
df['production_countries'] = df['production_countries'].apply(clean_text)
df['genres'].replace('[]', np.nan, inplace=True)
df['production_countries'].replace('[]', np.nan, inplace=True)
df['production_countries'].replace("['XX']", np.nan, inplace=True)
df['genres'].fillna('Unknown', inplace=True)
df['production_countries'].fillna('Unknown', inplace=True)
cols =['imdb_score','tmdb_popularity']
df[cols] = df[cols].apply(lambda x: x.fillna(x.median()))
# Convert 'tmdb_popular' column to integer type to remove decimal values
df['tmdb_score'] = df['tmdb_score'].astype(int)
# Out:
# /tmp/ipykernel_12235/844784539.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['genres'].replace('[]', np.nan, inplace=True)
# /tmp/ipykernel_12235/844784539.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
df.to_csv('/content/drive/MyDrive/pandaswork prime video cleaned data.csv')

# %%
#define threshold  using IQR method  - runtime
Q1 = df['runtime'].quantile(0.25)
print(Q1)
Q3 = df['runtime'].quantile(0.75)
print(Q3)
IQR = Q3 - Q1
print(IQR)

upper_threshold = Q3 + 1.5 * IQR

lower_threshold = Q1 - 1.5 * IQR
print(upper_threshold , lower_threshold)
# Out:
# 67.0
# 103.0
# 36.0
# 157.0 13.0

# %%
#flag outliers for further review
condition = (df['runtime'] > upper_threshold ) | (df['runtime'] < lower_threshold)
df['outlier_flag'] = condition

# %% [markdown]
# # **data cleaning of 2nd csv file**

# %%
df2 = pd.read_csv('/content/drive/MyDrive/pandaswork/credits.csv/credits.csv')

# %%
print(df2.columns)
# Out:
# Index(['person_id', 'id', 'name', 'character', 'role'], dtype='object')

# %%
df2.head()
# Out:
#    person_id       id           name      character   role
# 0      59401  ts20945     Joe Besser            Joe  ACTOR
# 1      31460  ts20945     Moe Howard            Moe  ACTOR
# 2      31461  ts20945     Larry Fine          Larry  ACTOR
# 3      21174  tm19248  Buster Keaton    Johnny Gray  ACTOR
# 4      28713  tm19248    Marion Mack  Annabelle Lee  ACTOR

# %%
df2.tail()
# Out:
#         person_id         id           name      character      role
# 124230    1938589  tm1054116  Sangam Shukla         Madhav     ACTOR
# 124231    1938565  tm1054116   Vijay Thakur  Sanjay Thakur     ACTOR
# 124232     728899  tm1054116  Vanya Wellens        Budhiya     ACTOR
# 124233    1938620  tm1054116   Vishwa Bhanu          Gissu     ACTOR
# 124234    1938620  tm1054116   Vishwa Bhanu            NaN  DIRECTOR

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124235 entries, 0 to 124234
# Data columns (total 5 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   person_id  124235 non-null  int64
#  1   id         124235 non-null  object
#  2   name       124235 non-null  object
#  3   character  107948 non-null  object
#  4   role       124235 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 4.7+ MB

# %%
df2.describe()
# Out:
#           person_id
# count  1.242350e+05
# mean   4.064737e+05
# std    5.616296e+05
# min    1.000000e+00
# 25%    3.899200e+04
# 50%    1.339490e+05
# 75%    5.712560e+05
# max    2.371153e+06

# %%
df2.isnull().mean()*100
# Out:
# person_id     0.000000
# id            0.000000
# name          0.000000
# character    13.109832
# role          0.000000
# dtype: float64

# %%
df2['character'].fillna('Not_Available', inplace=True)
# Out:
# /tmp/ipykernel_12235/3513033744.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2['character'].fillna('Not_Available', inplace=True)

# %%
df2['character'].replace({'Not_Available' : 'Not Available'}, inplace=True)

# %%
df2.duplicated().sum()
# Out:
# np.int64(56)

# %%
df2_dublicate = df2[df2.duplicated()]

# %%
df2 = df2.drop_duplicates()

# %%
def basic_clean(text):
  return str(text).lower().strip()

# %%
# Identify the columns that are strings and need cleaning
string_cols_to_clean = ['id', 'name', 'character', 'role']

# Apply the basic_clean function to each of these columns individually
for col in string_cols_to_clean:
    df2[col] = df2[col].apply(basic_clean)

# %%
def clean_text(text):
    if pd.isna(text):
        return ""
    text = text.lower()                     # Lowercase
    text = text.strip()                     # Strip outer whitespace
    text = text.replace('!', '').replace('#', '')  # Remove specific symbols
    for char in ['@', '$', '%', '^', '&', '*', '(', ')', '-', '_', '=', '+', '[', ']', '{', '}', '|', ':', ';', '"', "'", '<', '>', ',', '.', '?', '/','\\','[]']:
        text = text.replace(char, '')
    return ''.join([i for i in text if not i.isdigit()] )

# %%
df2['name'] = df2['name'].apply(clean_text)

# %%
df2['character'] = df2['character'].apply(clean_text)

# %%
df2['role'] = df2['role'].apply(clean_text)

# %%
df2.isnull().sum()
# Out:
# person_id    0
# id           0
# name         0
# character    0
# role         0
# dtype: int64

# %%
df2['role'].unique()
# Out:
# array(['actor', 'director'], dtype=object)

# %%
df2.to_csv('/content/drive/MyDrive/pandaswork prime video cleaned credits.csv')

# %%
df = pd.read_csv('/content/drive/MyDrive/pandaswork prime video cleaned data.csv')

# %%
df2.head()
# Out:
#    person_id       id           name      character   role
# 0      59401  ts20945     joe besser            joe  actor
# 1      31460  ts20945     moe howard            moe  actor
# 2      31461  ts20945     larry fine          larry  actor
# 3      21174  tm19248  buster keaton    johnny gray  actor
# 4      28713  tm19248    marion mack  annabelle lee  actor

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# Answer Here. filled the null value with median and with text ,droped duplicated value,cleaned special character and white space

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1 Univirate Anylasis

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
#dataset columns
print(df.columns)
# Out:
# Index(['id', 'title', 'type', 'description', 'release_year',
#        'age_certification', 'runtime', 'genres', 'production_countries',
#        'seasons', 'imdb_id', 'imdb_score', 'imdb_votes', 'tmdb_popularity',
#        'tmdb_score', 'tmdb_popular', 'imdb_scoreity'],
#       dtype='object')

# %%
# Chart - 1 visualization code
#Histplot
sns.histplot(data=df,x='release_year',bins = 30)
plt.title('Number of movie or series release per year ')
plt.xlabel('Release Year')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Answer Here. Because histplot is used for Univriate analysis of numerical columns

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Answer Here:- From the chart i obesrve an upward trend nearly from 2000 to 2020.
# it is indicating that amazon has invested more in increasing content library and expending into more country.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Looking at release year trends helps us make better business decisions. It shows what kind of content works best over time, so we can plan what to create next. It also helps in deciding where to spend money and effort. By understanding these patterns, we can attract more audience and grow the business.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
#histplot

sns.histplot(df['imdb_score'],bins = 30, kde=True)
plt.title('count of imdb score')
plt.xlabel('imdb_score')
plt.ylabel('count')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# Because histplot is used for Univriate analysis of numerical columns and Shows distribution shape.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the chart i can say that the imdb score for most movies and series are centered around 6 to 7.
# The peak is around 6 which mens most of the content is average or slighetly higher then average

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes,these insights can help as most of the content rated are average.
# So, improving content can help in the viwership,better reviews,strong brand value overall impact on businesss because viwer watch only high reted stuff
#
# yes, because very few high quality content are there that rated 8+,
# These can lead to lower audience retention and less competative advantage in market and the result will be cancellation of Subscription Plan

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
# Pie chart
df['type'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title('Distribution of Content Types')
plt.axis('equal')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# because A pie chart is ideal when you want to compare proportions of categorical univariate
#
#  in this case, the proportion of Movies vs TV Shows on Amazon Prime.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The insight that i found from the pie chart is the distribution of movie is nearly 87% and the tv shows is only 13%
# it is clearly seen that the amazon prime is more focused on movie in its content strategy

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# it is indicating low diversifaction in content diversity less variety can reduce long term user engagement and retention and can missed audience segments who prefer series rather then movie.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
#Line plot
# Calculate the average imdb_score for each release_year
avg_imdb_score_by_year = df.groupby('release_year')['imdb_score'].mean().reset_index()

sns.lineplot(x='release_year', y='imdb_score', data=avg_imdb_score_by_year)
plt.title('Average IMDb Score Over Release Years')
plt.xlabel('Release Year')
plt.ylabel('Average IMDb Score')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# for showing trend over time line chart are compatable on avg imdb score over year

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Early year(1920s - 1930s) show the avg rating are on higher side and the seen a dip and flucation in 1940s - 70s and form 1980s score are more stable and recent year slightly improvment are there.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Imdb score are constent over the year and slightly improvement are there in recent year so scope for investment and growth are there
#
# so, there is no upward trend are seen most of the content are average may lead to low differentation from competitors.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
#barplot

sns.barplot(data=df, x='type', y='imdb_score', estimator='mean', hue='type', palette='Set2', legend=False)
plt.title("Average IMDb Score by Content Type")
plt.xlabel("Type")
plt.ylabel("Average IMDb Score")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar plot is ideal for showing comparative statistics, like mean IMDb scores across categories.(continous V/S categorical)

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# from the chart it is clearly seen that the Avg rating of show is higher then the movie.
# investing in shows can drive higher engagement and may be increase in subscriber

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# investing in shows can increase user engagment and retention.
# Helps in creating high-quality, binge-worthy content, attracting more users.
#
# movies have lower rating so may be slightly dip can be seen.
# Increase focus on high-rated shows and improve movie quality to drive better business growth

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
# box plot
sns.boxplot(x='age_certification', y='imdb_score', data=df, hue='age_certification', palette='Set3', legend = False)
plt.title('IMDb Score by Age Certification')
plt.xlabel('Age Certification')
plt.ylabel('IMDb Score')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It shows the clear distribution how IMDb scores vary across different age certifications (like G, PG, PG-13, R, etc.).
# and it best for compare between continous vs categorical columns

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# from the box plot several insights has been emerge like some of them have higher imdb rating and some of them are lower imdb rating on age_certification

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# The insights offer a strategic advantage to improve content planning, drive user engagement, and allocate resources more effectively — all of which contribute to positive business outcomes.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7 visualization code
#countplot
sns.countplot(x='type', data=df, palette='cool',hue = 'type' ,legend = False)
plt.title('Distribution of Content Type (Movies vs Shows)')
plt.xlabel('Type')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The type variable (Movie or Show) is categorical, and count plots are ideal to display the frequency distribution of such data.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The count of Movies are significantly much higher then Tv Shows on amazon prime

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the insights from this chart can support several strategic and operational decisions that drive positive business impact, such as: The dominance of movies suggests Amazon Prime may need to balance its content portfolio by investing more in TV shows, which have higher user engagement and subscription retention.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8 visualization code
# Filter the DataFrame for runtime up to 300 minutes
df_filtered_runtime = df[df['runtime'] <= 300]

sns.scatterplot(x='runtime', y='imdb_score', hue='type', data=df_filtered_runtime, alpha=0.7)
plt.title('Runtime vs IMDb Score by Content Type')
plt.xlabel('Runtime (minutes)')
plt.ylabel('IMDb Score')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# It’s ideal for examining the relationship between two continuous variables, in this case, runtime and IMDb score.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Movies are generally wider spread of runtime ranging from very short film to over 150 min while tv shows have a cluster around curtaun time ranage per episode (around 30 - 60 min )

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Both movie and tv shows are tend to fall within same imdb rating i.e 6 to 8 but some outlier exist that have higher rating or poorely rated
#
# yes,from these chart we can say that insights can help create a positive business impact in several ways:
#
# Prioritize high-quality, engaging content (especially shows) over longer duration to drive better growth

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 9 visualization code
sns.countplot(x='age_certification', hue='type', data=df, palette='pastel')
plt.xticks(rotation=45)
plt.title('Content Type Distribution by Age Certification')
plt.xlabel('Age Certification')
plt.ylabel('Count')
plt.legend(title='Type')
plt.show()

# %% [markdown]
# 1. Why did you pick the specific chart?

# %% [markdown]
# It is ideal for showing the distribution of categorical variables, in this case, how content is spread across different age certification levels (like G, PG, PG-13, R, etc.).
#
# By using the hue='type' parameter, we can compare the distribution between Movies and TV Shows within each age rating category — giving us a dual perspective in a single chart.

# %% [markdown]
# 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the count plot "Content Type Distribution by Age Certification", the following insights can be drawn:
#
# Dominant Age Certification Categories:
# Certain age certifications (e.g., TV-MA, R, PG-13) may have a higher volume of content, indicating that the platform focuses more on teen or adult audiences.
#
# Movies vs TV Shows by Age Group:
# The hue='type' setting reveals how Movies and TV Shows are distributed across different age certifications:

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# By knowing which age groups are most served (e.g., adults via TV-MA or R-rated content), the platform can optimize marketing campaigns to target those demographics more effectively — leading to higher engagement and conversions.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 10 visualization code
## Select relevant numeric columns
selected_cols = ['runtime', 'imdb_score', 'imdb_votes', 'tmdb_popularity', 'tmdb_score']
important_data = df[selected_cols]
# Calculate correlation matrix
corr_matrix = important_data.corr()

# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm", linewidths=0.5)
plt.title("Correlation Heatmap of IMDb & TMDB Metrics")
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A heatmap is the best tool for displaying a correlation matrix, showing how strongly numerical variables (like IMDb score, TMDB score, popularity, runtime, etc.) are linearly related to one another.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# If the heatmap shows a high correlation (e.g., 0.7 to 0.9) between imdb_score and tmdb_score, it indicates that both platforms generally agree on content quality.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# TMDb popularity & score (0.26) show that higher popularity slightly leads to better ratings → useful for marketing and promotion strategies
#
# Focus on engagement-driven, high-quality content rather than runtime or popularity alone to drive better growth

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
# Select numeric columns and add content type
selected_cols = df[['runtime', 'imdb_score', 'imdb_votes', 'tmdb_popularity', 'tmdb_score', 'type']]
# Pair Plot visualization code
sns.pairplot(selected_cols, hue='type', corner=True)
plt.suptitle("Pair Plot of IMDb and TMDB Metrics by Content Type", y=1.02)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot shows scatter plots between all pairs of selected numerical features (like imdb_score, tmdb_score, runtime, popularity), allowing us to explore their relationships in one view.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the "Pair Plot of IMDb and TMDB Metrics by Content Type", several key insights can be drawn: IMDb score and TMDB score likely show a strong positive linear relationship, confirming that content rated highly on one platform tends to be rated similarly on the other.

# %% [markdown]
# ###Chart - 12

# %%
# Chart - 12 visualization code
# merging
df_merged = pd.merge(df, df2, on='id', how = 'inner')
df_merged.head()
actor_analysis = df_merged.groupby('name')['imdb_score'].agg(['mean','count']).reset_index()
actor_analysis = actor_analysis[actor_analysis['count'] >= 5]

top_actors = actor_analysis.sort_values('mean', ascending=False).head(10)

# Plot
sns.barplot(data=top_actors, x='name', y='mean')
plt.xticks(rotation=45)
plt.title("Top Actors by IMDb Rating")
plt.show()

# %% [markdown]
# By these bar plot i can say that all top actors have ratings close to 8, showing consistently high performance
# competative  performance is there
#
# Casting these actors can increase chances of high-rated content

# %% [markdown]
# ###Chart - 12

# %%
# Chart - 13 visualization code

# Filter df_merged to only include entries where the role is 'actor'
df_actor_roles = df_merged[df_merged['role'] == 'actor']

sns.countplot(data=df_actor_roles, x='type', hue='type', palette='cool', legend=False)

plt.xticks(rotation=45)
plt.title("Number of Actor Roles by Content Type")
plt.xlabel("Content Type")
plt.ylabel("Number of Actor Roles")
plt.show()

# %% [markdown]
# By looking these count plot we can say that the number of actor is higher in movie and it is obvious because number of movie is much higher then Tv shows
#
# Heavy focus on movies risk of over-dependence on one content type
# Opportunity to expand shows for better engagement and content balance

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To help the client (e.g., Amazon Prime Video or a similar streaming platform) achieve their business objective—such as increasing viewership, improving customer satisfaction, and maximizing ROI—the following data-driven strategic suggestions can be made based on the analysis and visual insights:
#
# 1. Focus on high quality content i.e 7+
# 2. increase investment in Tv Shows as shows have better rating then movies.
# 3. Improve movie quality as volume of movie is high but they are lacking in consistency
# 4. balance the content avoid the over dependency on movies, increase the content of Tv series and diverse the category

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# From all the analysis, I understand that content quality matters more than anything else. Shows are performing better and are more consistent, while movies are more but not always good in quality. Runtime and popularity don’t affect ratings much.
#
# So, to achieve business goals, we should focus on making better quality content, increase shows, improve movie quality, and use data to take decisions. This will help in getting more users and better growth

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
